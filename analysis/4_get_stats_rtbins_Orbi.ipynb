# %% [markdown]
# # Get stats on Orbitrap datasets
#
# This notebook explains the delta values within an RT window via isotopologues, adducts and fragments.
#
# **How many features do they explain?**
#
# Redo khipus using updated grid.
#
# 1. Get number of khipus per dataset, using updated grid.
# 2. Num total features within a RT khipu window.
# 3. How many are explained by probable fragments; num of features and khipus.
# 4. Compare MS2 for applicable khipus (neutral mass in MONA).
# 5. Check RT distribution for ions and fragments.

# %%
import sys
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks 
from scipy.ndimage import uniform_filter1d
import statsmodels.api as sm
from khipu.extended import peaklist_to_khipu_list, export_empCpd_khipu_list

sys.path.append("/Users/lish/li.github/consensus_serum_metabolome/utils")
from mining import *
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# pos ionization
isotope_search_patterns = [ (1.003355, '13C/12C', (0, 0.8)),
                            (2.00671, '13C/12C*2', (0, 0.8)),
                            (3.9948, '44Ca/40Ca', (0, 0.1)), # 2%
                            (1.9970, '37Cl/35Cl', (0.1, 0.8)), # 24.24%
                            ]

adduct_search_patterns = [  # initial patterns are relative to M+H+
                            (21.98194, 'Na/H'),
                            (41.026549, 'ACN'),     # Acetonitrile
                            (67.987424, 'NaCOOH'),
                            (37.955882, 'K/H'),
                            ]

# %%
orbi_datasets = [x.rstrip() for x in open('selected_45_orbi_datasets.txt').readlines()]
pos_orbi_datasets = [x for x in orbi_datasets if 'pos' in x]
neg_orbi_datasets = [x for x in orbi_datasets if 'neg' in x]

dict_tablefiles = {}
for line in open('list_input_files.tsv').readlines():
    a = line.rstrip().split('\t')
    dict_tablefiles[a[0]] = a[1]

dict_tablefiles[orbi_datasets[0]]
# Out:
# '/Users/lish/li.proj/serum_consensus_metabolome/orbitrap_v2/ST001237/study/HILICpos/B2/asari_ST001237_HILICpos_B2_ppm5_3524314/export/full_Feature_table.tsv'

# %%
dict_rtwindow = {}
for line in open('elution_parameters_45studies.tsv').readlines()[1:]:
    a = line.rstrip().split('\t')
    dict_rtwindow[a[0]] = float(a[5])
    
dict_rtwindow[orbi_datasets[0]]
# Out:
# 0.613

# %%
def get_comprehensive_stats_per_dataset(file, dict_tablefiles, dict_rtwindow, ion_mode):
    '''
    returns list_khipus, all_assigned_fids, remaining_features
    all_assigned_fids are for features in khipus.
    '''
    _n, list_features = read_features_from_asari_table(
        open(dict_tablefiles[file]).read()
        )
    for f in list_features:
        f['representative_intensity'] = f['peak_area']
    list_khipus, all_assigned_fids = peaklist_to_khipu_list(
                            list_features, 
                            isotope_search_patterns=isotope_search_patterns, 
                            adduct_search_patterns=adduct_search_patterns,
                            extended_adducts=[],    # not to confuse later analysis of ISF
                            mz_tolerance_ppm=5,
                            rt_tolerance=dict_rtwindow[file],
                            mode=ion_mode,
                            charges=[1, 2, 3],
                            )
    # remaining_features = [f for f in list_features if f['id'] not in all_assigned_fids]
    return export_empCpd_khipu_list(list_khipus), all_assigned_fids, list_features
    
def get_features_in_rtwindow(list_features, rt_ref, rt_stdev):
    '''
    returns features in list_features that are within rt_stdev
    '''
    return [f for f in list_features if abs(f['rtime']-rt_ref) <= rt_stdev]   

def get_khipus_in_rtwindow(list_khipus, rt_ref, rt_stdev):
    '''
    returns features in list_features that are within rt_stdev
    '''
    return [f for f in list_khipus if abs(f['MS1_pseudo_Spectra'][0]['rtime']-rt_ref) <= rt_stdev]

# %%
dict_rtwindow[orbi_datasets[0]]
# Out:
# 0.613

# %%
list_khipus, all_assigned_fids, list_features = get_comprehensive_stats_per_dataset(
    orbi_datasets[0], dict_tablefiles, dict_rtwindow, 'pos'
)
# Out:
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '1120a_Marios_PD1_Inhib2_HP-PREFA58', '1040_Marios_PD1_Inhib2_HP-EA717425-8', '1040a_Marios_PD1_Inhib2_HP-PREFA54', '1040b_Marios_PD1_Inhib2_HP-PREFB54', '1041_Marios_PD1_Inhib2_HP-E9133655-7', '1042_Marios_PD1_Inhib2_HP-L1376088-6', '1043_Marios_PD1_Inhib2_HP-L1305560-7', '1044_Marios_PD1_Inhib2_HP-L1370589-6', '1045_Marios_PD1_Inhib2_HP-E9123619-6']
# Read 57875 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 92 features, highest peak at F21467
# Downsized input network with 81 features, highest peak at F5884
# Downsized input network with 37 features, highest peak at F866
# Downsized input network with 27 features, highest peak at F14774
# Downsized input network with 34 features, highest peak at F43165
# Downsized input network with 49 features, highest peak at F53938
# Constructed 5382 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 680 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 202 khipus in this round.

# %%
remaining_features = [f for f in list_features if f['id'] not in all_assigned_fids]
len(list_khipus), len(all_assigned_fids), len(remaining_features)
# Out:
# (6264, 15077, 42798)

# %%
list_khipus[1999]
# Out:
# {'interim_id': 'kp2000_320.235',
#  'neutral_formula_mass': 320.23504603323,
#  'neutral_formula': None,
#  'Database_referred': [],
#  'identity': [],
#  'MS1_pseudo_Spectra': [{'id_number': 'F33277',
#    'id': 'F33277',
#    'mz': 321.2422,
#    'rtime': 101.28,
#    'apex': 101.28,
#    'left_base': 98.07,
#    'right_base': 103.96,
#    'parent_masstrack_id': '321.2422',
#    'peak_area': '118276008',
#    'cSelectivity': '0.9',
#    'goodness_fitting': '0.95',
#    'snr': '105',
#    'detection_counts': '96',
#    'representative_intensity': '118276008',
#    'isotope': 'M0',
#    'modification': 'M+H+',
#    'ion_relation': 'M0,M+H+'},
#   {'id_number': 'F34809',
#    'id': 'F34809',
#    'mz': 322.2458,
#    'rtime': 100.75,
#    'apex': 100.75,
#    'left_base': 97.81,
#    'right_base': 103.96,
#    'parent_masstrack_id': '322.2458',
#    'peak_area': '8702103',
#    'cSelectivity': '0.97',
#    'goodness_fitting': '0.81',
#    'snr': '713',
#    'detection_counts': '9',
#    'representative_intensity': '8702103',
#    'isotope': '13C/12C',
#    'modification': 'M+H+',
#    'ion_relation': '13C/12C,M+H+'}],
#  'MS2_Spectra': []}

# %%
_bins = []
for k in list_khipus:
    M0 = get_M0(k['MS1_pseudo_Spectra'])
    _bins += [f['id'] for f in get_features_in_rtwindow(remaining_features, M0['rtime'], 0.613)]
len(_bins), len(set(_bins))
# Out:
# (807191, 36657)

# %%
all_features = [] + remaining_features
for k in list_khipus:
    all_features.append(get_M0(k['MS1_pseudo_Spectra']))
len(all_features)
# Out:
# 49062

# %% [markdown]
# **Not many features are out of khipu+rt windows.**
#
# Now search against each khipu, to see how many ISFs may exist.

# %%
candidate_fragments = '''14.0155	792	14.0155	['14.01565', "± CH2, alkane chains, waxes, fatty acids, methylation; or '-[C3H6ON] <-> -[C2H4ON], acrylamide versus iodoacetamide in cysteine alkylation (gels)", "{'C': 1, 'H': 2}"]
18.0104	780	18.0104	['-18.010565', 'H2O', "{'H': -2, 'O': -1}"]
2.0156	634	2.0156	['2.01565', '± 2H, opening or forming of double bond', "{'H': 2}"]
28.0312	550	28.0312	['28.0313', '± C2H4, natural alkane chains such as fatty acids', "{'C': 2, 'H': 4}"]
15.9948	420	15.9948	['15.99492', '± O, e.g. oxidation/reduction', "{'O': 1}"]
17.0264	404	17.0264	['-17.026549', 'NH3', "{'N': -1, 'H': -3}"]
26.0155	392	26.0155	[' C2H2']
27.9948	385	27.9948	['27.99492', '± CO', "{'C': 1, 'O': 1}"]
32.026	311	32.0261	['32.026215', 'MeOH', "{'C': 1, 'H': 4, 'O': 1}"]
42.0104	301	42.0104	['42.01057', '± COCH2', "{'C': 2, 'O': 1, 'H': 2}"]
67.9872	295	67.9873	['67.987424', 'NaCOOH', "{'C': 1, 'O': 2, 'Na': 1, 'H': 1}"]
13.9791	287	13.9791	['13.97927', 'O <-> 2H, e.g. Oxidation follwed by H2O elimination', "{'H': -2, 'O': 1}"]
42.0468	278	42.0468	['42.04695', '± C3H6, propylation', "{'C': 3, 'H': 6}"]
46.0053	277	46.0053	['-46.005479', 'H2O+CO', "{'C': -1, 'H': -2, 'O': -2}"]
'''
candidate_fragments = [
    (float(x.split()[0]), x) for x in candidate_fragments.splitlines()
]
len(candidate_fragments), candidate_fragments[3]
# Out:
# (14,
#  (28.0312,
#   '28.0312\t550\t28.0312\t[\'28.0313\', \'± C2H4, natural alkane chains such as fatty acids\', "{\'C\': 2, \'H\': 4}"]'))

# %%
# sort khipus by mass
list_khipus = sorted(list_khipus, key=lambda x: x['neutral_formula_mass'], reverse=True)

# %%
def mz_in_list(mz, mlist, max_diff=0.0005, ppm=5):
    '''
    mz can be zero, which is False match.
    '''
    r = False
    if mz > max_diff:
        deltas = sorted([abs(x-mz) for x in mlist])
        if deltas[0] <= max_diff or deltas[0]/mz < ppm*1e-6:
            r = True
    return r 
    
def explain_a_dataset(list_khipus, remaining_features, isf_candidate_fragments, rt_stdev=0.613):
    '''
    by isf_candidate_fragments
    '''
    explained_khipu_ids, explained_feature_ids = [], []
    delta_values_used = []
    
    for ii in range(len(list_khipus)-1):
        rt_ref = list_khipus[ii]['MS1_pseudo_Spectra'][0]['rtime']
        base_mz = get_M0(list_khipus[ii]['MS1_pseudo_Spectra'])['mz']
        khipus_in_rtwindow = get_khipus_in_rtwindow(
            list_khipus[ii+1:], 
            rt_ref, 
            rt_stdev)
        for k in khipus_in_rtwindow:
            _d = list_khipus[ii]['neutral_formula_mass']-k['neutral_formula_mass']
            if mz_in_list(_d, isf_candidate_fragments):
                explained_khipu_ids.append(k['interim_id'])
                delta_values_used.append(_d)
            
        features_in_rtwindow = get_features_in_rtwindow(
            remaining_features, 
            rt_ref, 
            rt_stdev)
        for f in features_in_rtwindow:
            _d = base_mz - f['mz']
            if mz_in_list(
                _d, isf_candidate_fragments
            ):
                explained_feature_ids.append(f['id'])
                delta_values_used.append(_d)
                
    return explained_khipu_ids, explained_feature_ids, delta_values_used

# %%
isf_candidate_fragments = [x[0] for x in candidate_fragments]

explained_khipu_ids, explained_feature_ids, delta_values_used = explain_a_dataset(list_khipus, 
                                                               remaining_features,
                                                               isf_candidate_fragments)
len(set(explained_khipu_ids)), len(set(explained_feature_ids))
# Out:
# (355, 1061)

# %%
sorted(delta_values_used)[600:606]
# Out:
# [15.994853099999943,
#  15.994855833333318,
#  15.994892499999992,
#  15.994899999999973,
#  15.994899999999973,
#  15.994899999999973]

# %% [markdown]
# **Common fragments do not explain many additional features**
#
# Above are not big numbers, given (5590, 44895) to start with.
#
#
# Try MoNA MS2 search next.

# %%
from matchms.importing import load_from_msp
from mass2chem.search import build_centurion_tree, find_all_matches_centurion_indexed_list

from asari.tools import match_features as mf
from asari.mass_functions import mass_paired_mapping, all_mass_paired_mapping

# %%
# from JM
path = '../annotation_sources/filtered_MoNA-export-LC-MS-MS_Positive_Mode.msp'

spectral_registry = {}
total = 0
for x in load_from_msp(path):
    try:
        inchikey = x.metadata_dict()['inchikey']
        if inchikey:
            if inchikey not in spectral_registry:
                spectral_registry[inchikey] = []
            spectral_registry[inchikey].append(x)
            total += 1
    except:
        pass

print("filtered MS2 Size: ", str(len(spectral_registry)), " Compounds with ", str(total), " MS2 Spectra")
# Out:
# 2024-12-03 13:58:30,007:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:30,091:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:42,778:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,780:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,781:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,782:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,783:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,784:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,786:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,787:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,788:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,789:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,789:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,790:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,791:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,792:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,793:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,793:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,794:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,795:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,796:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,797:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,798:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,799:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,799:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,803:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:42,829:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:43,201:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:43,371:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:43,575:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:43,859:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:43,890:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:43,905:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:43,938:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:43,941:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:44,590:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:44,704:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,093:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,101:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,141:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,155:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,155:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,156:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,157:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,158:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,265:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,546:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,679:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,684:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,700:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,734:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,891:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,931:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:45,956:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,032:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,035:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,042:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,087:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,126:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,132:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,139:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,149:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,151:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,161:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,169:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,366:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-03 13:58:46,372:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:46,614:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,380:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,382:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,412:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,418:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,419:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,420:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,421:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,422:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,423:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,424:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,424:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,425:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,426:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,427:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,427:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,428:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,429:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,430:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,431:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,431:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,432:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,433:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,434:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,434:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,435:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,436:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,436:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,438:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,439:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,440:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,441:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,441:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,442:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,442:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,443:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,444:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,445:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,446:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,446:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,447:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,448:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,449:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,449:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,450:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,451:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,452:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,452:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,453:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,454:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,454:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,455:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,456:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,456:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,458:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,459:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,459:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,460:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,461:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,461:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,462:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,463:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,463:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,464:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,465:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,466:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,467:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,467:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,468:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,469:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,469:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,470:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,472:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,472:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,473:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,474:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,475:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,476:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,477:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,478:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,479:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,479:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,480:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,481:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,482:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,482:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,483:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,484:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,484:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,485:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,487:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,488:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,488:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,489:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,490:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,491:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,493:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,496:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,496:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,497:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,498:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,498:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,499:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,501:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,502:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,502:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,503:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,504:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,504:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,505:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,506:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,508:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,509:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,509:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,511:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,511:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,512:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,512:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,513:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,515:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,515:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,516:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,518:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,519:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,519:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,520:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,522:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,523:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,523:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,524:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,525:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,525:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,526:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,527:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,527:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,528:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,529:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,530:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,530:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,531:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,532:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,540:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,541:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,542:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,543:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,543:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,545:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,545:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,546:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,547:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,547:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,548:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,549:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,550:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,550:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,552:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,552:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,554:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,554:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,555:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,556:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,558:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,558:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,559:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,560:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,560:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,562:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,563:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,563:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,564:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,566:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,566:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,567:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,568:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,569:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,570:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,571:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,572:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,574:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,575:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,576:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,583:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,585:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,585:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,586:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,587:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,588:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,589:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,590:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,591:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,592:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,593:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,593:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,594:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,599:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,599:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,600:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,601:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,601:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,602:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,603:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,604:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,606:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,606:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,607:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,608:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,608:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,609:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,612:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,613:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,614:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,615:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,616:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,617:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,618:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,619:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,619:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,620:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,621:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,622:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,623:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,626:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,627:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,627:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,628:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,629:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,630:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,631:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,632:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,633:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,634:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,635:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,636:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,637:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,638:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,639:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,641:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,642:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-03 13:58:47,782:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Unfiltered MS2 Size:  13972  Compounds with  13972  MS2 Spectra

# %%
spectral_registry['AACVPYUISGWNOU-WYMPLXKRSA-N']
# Out:
# [Spectrum(precursor m/z=1063.54, 413 fragments between 76.0 and 1806.6)]

# %%
def extract_ms2_spectrum(sp, N=5):
    '''
    returns _precursor, _name, top N (intensity, mz)
    '''
    _d = sp.metadata_dict()
    _precursor, _name = _d['precursor_mz'], _d['compound_name']
    imz = zip(sp.peaks.intensities, sp.peaks.mz)
    imz = [x for x in imz if x[1] < _precursor - 0.01] # excluding _precursor
    return _precursor, _name, sorted(imz, reverse=True)[:N]

extract_ms2_spectrum(spectral_registry['AACVPYUISGWNOU-WYMPLXKRSA-N'][0])
# Out:
# (1063.54,
#  'NCGC00385453-01_C53H84O20_(3beta,12beta,14beta)-3-{[beta-D-Glucopyranosyl-(1->4)-6-deoxy-3-O-methyl-beta-D-glucopyranosyl-(1->4)-2,6-dideoxy-3-O-methyl-beta-D-ribo-hexopyranosyl-(1->4)-2,6-dideoxy-3-O-methyl-beta-D-ribo-hexopyranosyl]oxy}-14-hydroxy-20-oxopregn-5-en-12-yl (2E)-2-methyl-2-butenoate',
#  [(26.896237, 489.196625),
#   (24.475206, 963.50415),
#   (15.594292, 964.493103),
#   (9.966106, 965.499939),
#   (4.45185, 490.196716)])

# %%
# ms2List is usable MoNA MS/MS compounds

ms2List, no_precursor = [], []
for sps in spectral_registry.values(): 
    try:
        ms2List.append(extract_ms2_spectrum(sps[0])) 
    except KeyError:
        no_precursor.append(sps[0])
        
print(len(ms2List))

mz_ms2List = [x[0] for x in ms2List]
mz_khipu_features = [get_M0(k['MS1_pseudo_Spectra'])['mz'] for k in list_khipus]
mz_remaining_features = [f['mz'] for f in remaining_features]

# How many precursors match
found_ms2list = all_mass_paired_mapping(mz_ms2List, mz_khipu_features, std_ppm=5)[0]
found_2_ms2list = all_mass_paired_mapping(mz_ms2List, mz_remaining_features, std_ppm=5)[0]

print(len(found_ms2list), len(found_2_ms2list))
# Out:
# 13672
# 3217 14884

# %%
found_ms2list[33]
# Out:
# (6218, 443)

# %%
mz_khipu_features[443], ms2List[6218]
# Out:
# (448.0956,
#  (448.096631171168,
#   'MMV671636',
#   [(1.06, 270.0732),
#    (0.81, 214.8437),
#    (0.3, 361.0909),
#    (0.17, 430.9724),
#    (0.17, 72.0323)]))

# %%
MS2flist = []
for x in ms2List:
    MS2flist.append({
        'mz': x[0],
        'rtime': 0,
        'name': x[1],
        'peaks': x[2]
    })
    
tree_MS2flist = build_centurion_tree(MS2flist)

# %%
def test_match_ms2(mzs_in_rtbin, ms2_fragments, limit_ppm=5):
    '''
    returns fragments that are matched in mzs_in_rtbin
    
    ms2_precursor and mz should already match before this.
    '''
    found = []
    if mzs_in_rtbin and ms2_fragments:
        for mz in ms2_fragments:
            if min([abs(mz-x) for x in mzs_in_rtbin]) < 0.000001*limit_ppm*mz:
                found.append(mz)
    return found

# %%
# 
# 
matched = []
for k in list_khipus:
    m0 = get_M0(k['MS1_pseudo_Spectra'])
    in_rtwindow = get_features_in_rtwindow(all_features, m0['rtime'], 0.613)
    in_rtwindow = [f['mz'] for f in in_rtwindow if f['mz'] < m0['mz']]
    # find matched precursor
    precursors = find_all_matches_centurion_indexed_list(m0['mz'], tree_MS2flist, limit_ppm=5)
    for sp in precursors:
        tested = test_match_ms2(in_rtwindow, [x[1] for x in sp['peaks']], 5)
        if tested:
            matched.append((k['interim_id'], sp, tested))

# %%
_more = []
for m in matched:
    _more += m[2]
    
len(_more), len(set(_more))
# Out:
# (509, 448)

# %%
matched2 = []
for ff in remaining_features:
    in_rtwindow = get_features_in_rtwindow(all_features, ff['rtime'], 0.613)
    in_rtwindow = [f['mz'] for f in in_rtwindow if f['mz'] < ff['mz']]
    # find matched precursor
    precursors = find_all_matches_centurion_indexed_list(ff['mz'], tree_MS2flist, limit_ppm=5)
    for sp in precursors:
        tested = test_match_ms2(in_rtwindow, [x[1] for x in sp['peaks']], 5)
        if tested:
            matched2.append((ff['id_number'], sp, tested))

# %%
_more = []
for m in matched+matched2:
    _more += m[2]
    
len(matched), len(matched2), len(_more), len(set(_more))
# Out:
# (377, 616, 1225, 1016)

# %%
matched[99]
# Out:
# ('kp2742_359.1429',
#  {'mz': 360.1485,
#   'rtime': 0,
#   'name': 'Rabeprazole',
#   'peaks': [(100.0, 210.12346),
#    (47.886888, 167.1178),
#    (11.076144, 193.09705),
#    (8.398393, 168.10135),
#    (8.348258, 150.09135)]},
#  [167.1178])

# %% [markdown]
# **1016 features are matched to any of the MS2 peaks, out of 993 precursors**
#
# Using 13672 cpds from MoNA.
#
# This dataset: 6264 khipus, (15077, 42798) features
#
# **Next, do all datasets. Pos data first.**

# %%
def explain_a_dataset_byMS2(all_features, ms2tree, rt_stdev, limit_ppm=5):
    '''
    tree_MS2flist = build_centurion_tree(MS2flist)
    example MS2:  {'mz': 209.081,
        'rtime': 0,
        'name': 'Pyrenocin A - NCGC00169582-02_C11H12O4_1H-2-Benzopyran-1-one, 3,4-dihydro-6-hydroxy-8-methoxy-3-methyl-',
        'peaks': [(100.0, 163.075516),
        (96.239927, 191.070282),
        (26.604602, 103.053802),
        (19.662868, 135.080414),
        (18.420266, 148.05191)]},
    example result from test_match_ms2: [191.070282]
    '''   
    matched2, _have_precursors = [], []
    for ff in all_features:
        in_rtwindow = get_features_in_rtwindow(all_features, ff['rtime'], rt_stdev)
        in_rtwindow = [x['mz'] for x in in_rtwindow if x['mz'] < ff['mz']+0.0005]
        # find matched precursor
        precursors = find_all_matches_centurion_indexed_list(
            ff['mz'], ms2tree, limit_ppm=limit_ppm)
        if precursors:
            _have_precursors.append(ff['id_number'])
        for sp in precursors:
            tested = test_match_ms2(in_rtwindow, [x[1] for x in sp['peaks']], limit_ppm)
            if tested:
                _deltas = [sp['mz']-x for x in tested]
                matched2.append((ff['id_number'], sp['name'], _deltas))
                
    return _have_precursors, matched2

# %%
# Run took 3 minutes for this dataset
matched2 = explain_a_dataset_byMS2(all_features, tree_MS2flist, 0.613, 5)

# %%
len(matched2), matched2[88], len(set([x[0] for x in matched2]))
# Out:
# (993, ('F12751', 'Amino adipic acid dimethyl ester', [60.02099999999999]), 688)

# %%
# Collect both explanation of 
# isf_candidate_fragments : frequent detal
# and MoNA MS2 peaks
# 110 minutes

tally_pos = []
for f in pos_orbi_datasets:
    list_khipus, all_assigned_fids, list_features = get_comprehensive_stats_per_dataset(
        f, dict_tablefiles, dict_rtwindow, 'pos'
        )

    list_khipus = sorted(list_khipus, key=lambda x: x['neutral_formula_mass'], reverse=True)
    remaining_features = [f for f in list_features if f['id'] not in all_assigned_fids]
    
    # by isf_candidate_fragments
    explained_khipu_ids, explained_feature_ids, delta_values_used = explain_a_dataset(
        list_khipus, remaining_features, isf_candidate_fragments, 
        rt_stdev=dict_rtwindow[f]
        )
    
    # by MoNA MS2
    have_precursors, matched2 = explain_a_dataset_byMS2(
        list_khipus, tree_MS2flist, rt_stdev=dict_rtwindow[f])
    delta_values_ms2 = []
    for x in matched2:
        delta_values_ms2 += x[2]
    
    tally_pos.append(
        {
            'study': f,
            'num_khipus': len(list_khipus),
            'num_features':  len(list_features),
            'mzdelta_explained_khipus': len(set(explained_khipu_ids)), 
            'mzdelta_explained_features': len(set(explained_feature_ids)),
            'freq_delta_values_used': delta_values_used,
            'have_precursors': len(have_precursors),
            'ms2_explained_features': len(matched2),
            'delta_values_ms2': delta_values_ms2,
        }
    )
# Out:
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '1120a_Marios_PD1_Inhib2_HP-PREFA58', '1040_Marios_PD1_Inhib2_HP-EA717425-8', '1040a_Marios_PD1_Inhib2_HP-PREFA54', '1040b_Marios_PD1_Inhib2_HP-PREFB54', '1041_Marios_PD1_Inhib2_HP-E9133655-7', '1042_Marios_PD1_Inhib2_HP-L1376088-6', '1043_Marios_PD1_Inhib2_HP-L1305560-7', '1044_Marios_PD1_Inhib2_HP-L1370589-6', '1045_Marios_PD1_Inhib2_HP-E9123619-6']
# Read 57875 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 92 features, highest peak at F21467
# Downsized input network with 81 features, highest peak at F5884
# Downsized input network with 37 features, highest peak at F866
# Downsized input network with 27 features, highest peak at F14774
# Downsized input network with 34 features, highest peak at F43165
# Downsized input network with 49 features, highest peak at F53938
# Constructed 5382 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 680 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 202 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'CB221-A', 'CB198-V', 'CB199-A', 'CB199-V', 'CB200-A', 'CB200-V', 'CB201-A', 'CB201-V', 'CB202-V']
# Read 166832 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 357 features, highest peak at F21308
# Downsized input network with 47 features, highest peak at F74757
# Downsized input network with 51 features, highest peak at F100907
# Downsized input network with 31 features, highest peak at F81358
# Downsized input network with 28 features, highest peak at F127939
# Constructed 14665 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Downsized input network with 35 features, highest peak at F49396
# Downsized input network with 37 features, highest peak at F50419
# Constructed 3372 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 345 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '254', '209', '21', '210', '211', '213', '214', '215', '216']
# Read 107975 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 28 features, highest peak at F52663
# Downsized input network with 27 features, highest peak at F53215
# Downsized input network with 34 features, highest peak at F49862
# Downsized input network with 48 features, highest peak at F53203
# Downsized input network with 39 features, highest peak at F61936
# Downsized input network with 26 features, highest peak at F69393
# Downsized input network with 29 features, highest peak at F67368
# Downsized input network with 32 features, highest peak at F72840
# Downsized input network with 27 features, highest peak at F76003
# Downsized input network with 37 features, highest peak at F78439
# Downsized input network with 49 features, highest peak at F106115
# Constructed 9015 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 1437 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 158 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'HILIC-JB-29', 'HILIC-JB-1', 'HILIC-JB-10', 'HILIC-JB-11', 'HILIC-JB-12', 'HILIC-JB-13', 'HILIC-JB-14', 'HILIC-JB-15', 'HILIC-JB-16']
# Read 68156 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 29 features, highest peak at F29221
# Downsized input network with 56 features, highest peak at F57253
# Downsized input network with 32 features, highest peak at F44858
# Downsized input network with 35 features, highest peak at F45657
# Downsized input network with 133 features, highest peak at F49698
# Downsized input network with 47 features, highest peak at F55767
# Downsized input network with 47 features, highest peak at F52650
# Downsized input network with 42 features, highest peak at F55459
# Downsized input network with 36 features, highest peak at F52810
# Constructed 5730 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Downsized input network with 39 features, highest peak at F55459
# Constructed 1127 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 378 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'METAB01_Smpl_3_nonCOVID', 'METAB01_QC1', 'METAB01_QC2', 'METAB01_QC3', 'METAB01_QC4', 'METAB01_QC5', 'METAB01_Smpl_07', 'METAB01_Smpl_100', 'METAB01_Smpl_10_nonCOVID']
# Read 203773 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 1745 features, highest peak at F165112
# Downsized input network with 169 features, highest peak at F125766
# Downsized input network with 55 features, highest peak at F148705
# Downsized input network with 40 features, highest peak at F127517
# Downsized input network with 82 features, highest peak at F159897
# Downsized input network with 35 features, highest peak at F175382
# Downsized input network with 112 features, highest peak at F158244
# Downsized input network with 38 features, highest peak at F108687
# Downsized input network with 28 features, highest peak at F168761
# Downsized input network with 44 features, highest peak at F156311
# Downsized input network with 62 features, highest peak at F160571
# Downsized input network with 62 features, highest peak at F203431
# Constructed 5348 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Downsized input network with 54 features, highest peak at F135711
# Downsized input network with 37 features, highest peak at F154712
# Downsized input network with 473 features, highest peak at F150589
# Downsized input network with 33 features, highest peak at F114220
# Downsized input network with 32 features, highest peak at F162140
# Constructed 2806 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 3055 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'QC2', 'ACN_0_A', 'ACN_0_B', 'ACN_0_BLANK', 'ACN_0_BLANK_01', 'ACN_0_C1', 'ACN_0_C2', 'ACN_0_C3', 'ACN_20C_A']
# Read 76457 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 75 features, highest peak at F21550
# Downsized input network with 57 features, highest peak at F74393
# Downsized input network with 58 features, highest peak at F16362
# Downsized input network with 32 features, highest peak at F37778
# Downsized input network with 69 features, highest peak at F54034
# Downsized input network with 35 features, highest peak at F51945
# Downsized input network with 85 features, highest peak at F65187
# Constructed 5845 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 882 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 161 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'VT_191125_M418_027', 'VT_191125_M418_001', 'VT_191125_M418_003', 'VT_191125_M418_005', 'VT_191125_M418_007', 'VT_191125_M418_009', 'VT_191125_M418_011', 'VT_191125_M418_013', 'VT_191125_M418_015']
# Read 46855 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 32 features, highest peak at F14748
# Downsized input network with 90 features, highest peak at F43997
# Downsized input network with 26 features, highest peak at F20703
# Downsized input network with 60 features, highest peak at F3779
# Downsized input network with 43 features, highest peak at F15176
# Downsized input network with 26 features, highest peak at F14576
# Downsized input network with 36 features, highest peak at F44581
# Downsized input network with 29 features, highest peak at F29766
# Downsized input network with 58 features, highest peak at F34938
# Downsized input network with 66 features, highest peak at F39711
# Downsized input network with 30 features, highest peak at F33875
# Downsized input network with 30 features, highest peak at F40967
# Downsized input network with 38 features, highest peak at F43760
# Downsized input network with 28 features, highest peak at F39733
# Downsized input network with 31 features, highest peak at F46608
# Constructed 5060 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Downsized input network with 29 features, highest peak at F44152
# Constructed 903 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 310 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'COV2-95+', 'COV2-02+', 'COV2-03+', 'COV2-04+', 'COV2-05+', 'COV2-07+', 'COV2-08+', 'COV2-09+', 'COV2-10+']
# Read 27515 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 36 features, highest peak at F25046
# Downsized input network with 42 features, highest peak at F9781
# Downsized input network with 417 features, highest peak at F9451
# Downsized input network with 46 features, highest peak at F2352
# Downsized input network with 29 features, highest peak at F1821
# Downsized input network with 43 features, highest peak at F5701
# Downsized input network with 32 features, highest peak at F5447
# Downsized input network with 36 features, highest peak at F23856
# Downsized input network with 31 features, highest peak at F7766
# Downsized input network with 39 features, highest peak at F21780
# Downsized input network with 29 features, highest peak at F22920
# Downsized input network with 29 features, highest peak at F22215
# Constructed 3035 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 755 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 26 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM15_39', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_03', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_04', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_05', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_06', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_07', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_08', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_09', 'QXA03POSLAT20160901_NCIA0316ML_HUMAN_SERUM13_10']
# Read 28969 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Constructed 3615 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 521 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 177 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'H-253+_20200220050835', 'H-210+', 'H-211+', 'H-212+', 'H-213+_20200220083558', 'H-214+_20200219234925', 'H-215+_20200220061222', 'H-216+_20200219175823', 'H-217+_20200220064416']
# Read 50647 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 26 features, highest peak at F4033
# Downsized input network with 39 features, highest peak at F868
# Constructed 5609 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 580 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 82 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'VT_140310_063', 'VT_140310_013', 'VT_140310_015', 'VT_140310_017', 'VT_140310_019', 'VT_140310_021', 'VT_140310_023', 'VT_140310_025', 'VT_140310_027']
# Read 33062 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 55 features, highest peak at F31771
# Downsized input network with 26 features, highest peak at F14443
# Downsized input network with 45 features, highest peak at F26118
# Downsized input network with 36 features, highest peak at F26154
# Downsized input network with 26 features, highest peak at F27518
# Downsized input network with 26 features, highest peak at F31889
# Constructed 1576 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 490 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 57 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'PZPa_S_170', 'PZPa_B_10', 'PZPa_B_11', 'PZPa_B_13', 'PZPa_B_16', 'PZPa_B_17', 'PZPa_B_20', 'PZPa_B_24', 'PZPa_B_3']
# Read 27364 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Constructed 1296 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 344 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 39 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'Lich_SP_48', 'Lich_HHEAR_1', 'Lich_HHEAR_2', 'Lich_HHEAR_3', 'Lich_HHEAR_4', 'Lich_HHEAR_5', 'Lich_HHEAR_6', 'Lich_HHEAR_7', 'Lich_HHEAR_8']
# Read 49322 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Constructed 3877 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 699 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 182 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'AG-108_r17+', 'AG-100_r64+', 'AG-101_r29+', 'AG-102_r86+', 'AG-103_r37+', 'AG-104_r87+', 'AG-105_r38+', 'AG-106_r50+', 'AG-107_r21+']
# Read 22843 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 38 features, highest peak at F9290
# Constructed 2178 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 404 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 15 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '71', '313', '314', '315', '316', '317', '319', '32', '320']
# Read 121340 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 30 features, highest peak at F6761
# Downsized input network with 73 features, highest peak at F61383
# Downsized input network with 37 features, highest peak at F39915
# Downsized input network with 32 features, highest peak at F47236
# Downsized input network with 36 features, highest peak at F42659
# Constructed 13874 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 2254 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 144 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'POS-JK-8', 'POS-JB-1', 'POS-JB-10', 'POS-JB-11', 'POS-JB-12', 'POS-JB-13', 'POS-JB-14', 'POS-JB-15', 'POS-JB-16']
# Read 147760 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 708 features, highest peak at F713
# Downsized input network with 31 features, highest peak at F23731
# Downsized input network with 211 features, highest peak at F86505
# Downsized input network with 42 features, highest peak at F12397
# Downsized input network with 40 features, highest peak at F35259
# Downsized input network with 28 features, highest peak at F5816
# Downsized input network with 32 features, highest peak at F63606
# Downsized input network with 286 features, highest peak at F95197
# Downsized input network with 32 features, highest peak at F36488
# ...
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 84 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '139', '1', '10', '100', '101', '102', '103', '104', '105_150908154023']
# Read 76745 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Constructed 6020 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 1120 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 129 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA2_36', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_03', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_05', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_06', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_08', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_10', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_13', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_15', 'QXA10POSEAR20170919_HSLO010217VWBL_HUMAN_PLASMA1_18']
# Read 21387 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Constructed 2670 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 263 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 13 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'Nexus_T21_4pos-97', 'Nexus_D21_4pos-15', 'Nexus_D21_4pos-16', 'Nexus_D21_4pos-17', 'Nexus_D21_4pos-19', 'Nexus_D21_4pos-20', 'Nexus_D21_4pos-31', 'Nexus_D21_4pos-32', 'Nexus_D21_4pos-35']
# Read 30113 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 613 features, highest peak at F7029
# Downsized input network with 42 features, highest peak at F1877
# Downsized input network with 40 features, highest peak at F3222
# Downsized input network with 39 features, highest peak at F21592
# Downsized input network with 37 features, highest peak at F8779
# Downsized input network with 78 features, highest peak at F22215
# Downsized input network with 74 features, highest peak at F17503
# Downsized input network with 38 features, highest peak at F18519
# Downsized input network with 30 features, highest peak at F15111
# Downsized input network with 27 features, highest peak at F11063
# Downsized input network with 38 features, highest peak at F11880
# Downsized input network with 39 features, highest peak at F16393
# Downsized input network with 31 features, highest peak at F28275
# Downsized input network with 27 features, highest peak at F27624
# Constructed 3623 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Constructed 910 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 65 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'OC222', 'OC144', 'OC145', 'OC146', 'OC147', 'OC148', 'OC149', 'OC15', 'OC150']
# Read 147506 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M+H+       Na/H        K/H        ACN     NaCOOH
# M0         1.007276  22.989216  38.963158  42.033825  68.994700
# 13C/12C    2.010631  23.992571  39.966513  43.037180  69.998055
# 37Cl/35Cl  3.004276  24.986216  40.960158  44.030825  70.991700
# 13C/12C*2  3.013986  24.995926  40.969868  44.040535  71.001410
# 44Ca/40Ca  5.002076  26.984016  42.957958  46.028625  72.989500
# Downsized input network with 30 features, highest peak at F25003
# Downsized input network with 26 features, highest peak at F76406
# Downsized input network with 32 features, highest peak at F3520
# Downsized input network with 188 features, highest peak at F19805
# Downsized input network with 130 features, highest peak at F50754
# Downsized input network with 44 features, highest peak at F95307
# Downsized input network with 29 features, highest peak at F4682
# Downsized input network with 251 features, highest peak at F19612
# Downsized input network with 213 features, highest peak at F15552
# Downsized input network with 456 features, highest peak at F63452
# Downsized input network with 72 features, highest peak at F52472
# Downsized input network with 26 features, highest peak at F7975
# Downsized input network with 36 features, highest peak at F7657
# Downsized input network with 26 features, highest peak at F24575
# Downsized input network with 26 features, highest peak at F35128
# Downsized input network with 33 features, highest peak at F58588
# Downsized input network with 82 features, highest peak at F68439
# Downsized input network with 52 features, highest peak at F77970
# Downsized input network with 58 features, highest peak at F8918
# Downsized input network with 37 features, highest peak at F21419
# Downsized input network with 26 features, highest peak at F60429
# Downsized input network with 30 features, highest peak at F38372
# Downsized input network with 28 features, highest peak at F41886
# Downsized input network with 29 features, highest peak at F48869
# Downsized input network with 28 features, highest peak at F68680
# Downsized input network with 26 features, highest peak at F80436
# Downsized input network with 29 features, highest peak at F72985
# Downsized input network with 42 features, highest peak at F65396
# Downsized input network with 26 features, highest peak at F61380
# Downsized input network with 26 features, highest peak at F72584
# Downsized input network with 34 features, highest peak at F79375
# Downsized input network with 49 features, highest peak at F52053
# Downsized input network with 26 features, highest peak at F45646
# Downsized input network with 40 features, highest peak at F88106
# Downsized input network with 35 features, highest peak at F47382
# Downsized input network with 48 features, highest peak at F73746
# Downsized input network with 29 features, highest peak at F74743
# Downsized input network with 29 features, highest peak at F60300
# Downsized input network with 47 features, highest peak at F81168
# Downsized input network with 50 features, highest peak at F101315
# Downsized input network with 56 features, highest peak at F90128
# Downsized input network with 428 features, highest peak at F143050
# Downsized input network with 37 features, highest peak at F137676
# Downsized input network with 204 features, highest peak at F138560
# Downsized input network with 26 features, highest peak at F147166
# Downsized input network with 34 features, highest peak at F147394
# Downsized input network with 41 features, highest peak at F132936
# Downsized input network with 26 features, highest peak at F125866
# Downsized input network with 27 features, highest peak at F145688
# Downsized input network with 27 features, highest peak at F133424
# Downsized input network with 26 features, highest peak at F122888
# Downsized input network with 26 features, highest peak at F132200
# Constructed 19809 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                             0.503638         11.998246        19.985217
# 13C/12C, 2x charged            1.005316         12.499924        20.486895
# 37Cl/35Cl, 2x charged          1.502138         12.996746        20.983717
# 13C/12C*2, 2x charged          1.506993         13.001601        20.988572
# 44Ca/40Ca, 2x charged          2.501038         13.995646        21.982617
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           21.520551           35.000988
# 13C/12C, 2x charged          22.022228           35.502666
# 37Cl/35Cl, 2x charged        22.519051           35.999488
# 13C/12C*2, 2x charged        22.523906           36.004343
# 44Ca/40Ca, 2x charged        23.517951           36.998388
# Downsized input network with 35 features, highest peak at F17826
# Downsized input network with 26 features, highest peak at F20310
# Downsized input network with 30 features, highest peak at F5965
# Downsized input network with 44 features, highest peak at F119918
# Downsized input network with 59 features, highest peak at F145745
# Downsized input network with 72 features, highest peak at F145636
# Constructed 4096 khipus in this round.
#
#
# Khipu search grid:
#                        M+H+, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                             0.335759          8.334590        13.659237
# 13C/12C, 3x charged            0.670210          8.669041        13.993689
# 37Cl/35Cl, 3x charged          1.001425          9.000256        14.324904
# 13C/12C*2, 3x charged          1.004662          9.003493        14.328140
# 44Ca/40Ca, 3x charged          1.667359          9.666190        14.990837
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           14.682793           23.669751
# 13C/12C, 3x charged          15.017244           24.004203
# 37Cl/35Cl, 3x charged        15.348459           24.335418
# 13C/12C*2, 3x charged        15.351696           24.338654
# 44Ca/40Ca, 3x charged        16.014393           25.001351
# Constructed 1892 khipus in this round.

# %%
len(tally_pos), tally_pos[8]['ms2_explained_features'], tally_pos[8]['mzdelta_explained_features']
# Out:
# (22, 844, 650)

# %%
len(tally_pos[8]['freq_delta_values_used']), len(tally_pos[8]['delta_values_ms2'])
# Out:
# (1360, 1030)

# %%
with open('isfExplained_result_tally_pos.json', 'w', encoding='utf-8') as f:
    json.dump(tally_pos, f,  ensure_ascii=False, indent=2)

# %% [markdown]
# **Neg data**

# %%
# neg ionization
isotope_search_patterns = [ (1.003355, '13C/12C', (0, 0.8)),
                            (2.00671, '13C/12C*2', (0, 0.8)),
                            (1.9970, '37Cl/35Cl', (0.1, 0.8)), # 24.24%
                            ]

adduct_search_patterns = [  # initial patterns are relative to M+H+
                            (21.98194, 'Na/H'), (67.987424, 'NaCOOH'),
                            (82.0030, 'C2HF3'),
                            (1.99566, 'F <-> OH'), 
                            ]

# %%
# reused from JM
path = '../annotation_sources/filtered_MoNA-export-LC-MS-MS_Negative_Mode.msp'

spectral_registry = {}
total = 0
for x in load_from_msp(path):
    try:
        inchikey = x.metadata_dict()['inchikey']
        if inchikey:
            if inchikey not in spectral_registry:
                spectral_registry[inchikey] = []
            spectral_registry[inchikey].append(x)
            total += 1
    except:
        pass

print("MS2 #: ", str(len(spectral_registry)), " Compounds with ", str(total), " MS2 Spectra")

ms2List, no_precursor = [], []
for sps in spectral_registry.values(): 
    try:
        ms2List.append(extract_ms2_spectrum(sps[0])) 
    except KeyError:
        no_precursor.append(sps[0])
        
print(len(ms2List))

MS2flist = []
for x in ms2List:
    MS2flist.append({
        'mz': x[0],
        'rtime': 0,
        'name': x[1],
        'peaks': x[2]
    })
    
tree_MS2flist = build_centurion_tree(MS2flist)
# Out:
# 2024-12-05 17:16:48,394:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:48,886:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:48,899:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,275:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,276:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,276:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,277:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,278:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,279:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,280:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,282:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,283:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,284:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,285:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,286:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,287:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,288:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,290:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,291:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,292:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,293:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,294:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,295:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,297:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,298:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,299:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,300:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,301:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,303:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,304:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,305:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,306:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,307:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,308:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,309:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,310:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,311:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,312:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,313:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,314:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,317:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,318:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,319:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,320:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,321:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,322:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,323:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,324:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,325:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,326:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,327:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,328:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,329:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,330:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,330:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,332:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,333:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,334:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,335:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,336:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,337:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,338:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,339:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,340:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,341:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,342:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,343:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,344:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,346:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,346:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,347:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,349:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,350:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,351:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,351:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,352:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,353:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,355:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,356:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,356:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,357:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,358:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,359:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,360:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,361:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,362:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,363:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,364:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,365:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,366:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,367:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,368:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,369:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,370:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,371:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,372:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,373:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,374:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,376:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,377:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,378:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,379:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,380:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,381:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,382:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,383:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,384:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,385:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,386:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,387:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,388:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,389:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,390:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,390:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,391:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,393:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,394:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,395:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,396:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,397:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,398:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,400:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,401:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,402:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,404:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,405:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,406:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,407:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,408:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,409:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,410:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,410:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,411:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,412:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,413:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,414:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,415:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,416:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,417:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,418:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,421:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,422:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,423:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,424:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,425:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,425:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,426:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,428:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,429:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,430:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,431:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,432:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,433:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,434:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,435:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,435:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,436:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,437:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,438:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,439:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,440:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,441:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,442:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,442:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,443:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,444:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,445:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,446:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,447:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,448:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,449:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,450:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,451:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,452:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,453:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,453:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,454:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,455:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,456:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,456:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,457:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,458:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,459:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,461:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,461:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,462:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,463:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,464:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,465:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,466:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,467:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,467:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,468:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,469:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,470:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,473:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,474:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,475:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,476:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,476:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,477:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,478:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,479:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,482:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,483:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,484:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,485:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,487:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,487:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,488:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,489:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,490:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,491:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,492:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,493:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,494:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,495:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,496:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,497:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,498:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,499:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,500:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,501:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,502:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,504:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,505:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,506:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,507:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,508:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,509:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,510:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,512:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,513:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,514:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,516:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,517:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,519:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,521:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,522:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,523:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,524:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,525:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,526:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,527:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,529:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,530:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,531:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,533:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,534:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,536:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,537:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,538:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,540:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,541:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,542:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,544:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,545:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,546:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,548:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,549:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,551:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,552:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,554:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,555:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,556:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,558:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,560:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,562:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,564:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,566:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,567:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,569:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,570:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,571:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,572:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,573:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,574:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,575:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,576:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,577:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,578:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,579:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,579:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,580:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,581:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,582:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,583:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,584:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,585:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,586:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,587:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,587:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,588:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,589:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,590:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,591:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,592:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,593:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,594:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,594:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,595:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,596:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,597:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,598:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,599:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,600:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,601:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,602:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,603:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,604:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,605:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,606:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,607:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,608:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,609:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,609:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,610:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,612:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,613:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,614:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,615:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,616:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,617:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,619:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,620:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,620:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,621:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,622:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,623:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,624:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,625:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,626:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,627:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,628:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,629:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,630:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,631:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,632:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,633:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,634:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,636:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,636:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,637:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,639:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,640:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,641:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,641:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,642:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,643:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,644:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,646:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,646:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,647:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,648:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,649:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,650:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,651:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,652:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,653:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,654:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,655:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,656:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,657:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,658:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,659:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,660:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,661:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,671:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:56,725:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,726:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,728:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,729:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,730:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,731:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,732:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,733:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,734:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,735:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,736:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,737:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,738:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,739:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,739:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,741:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,742:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,742:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:56,748:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:56,754:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:56,767:WARNING:matchms:add_retention:None can't be converted to float.
# 2024-12-05 17:16:57,291:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,323:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,324:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,325:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,326:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,336:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,380:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,381:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,384:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,386:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,387:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,872:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,873:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:57,884:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,036:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,037:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,073:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,076:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,076:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,077:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,078:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,079:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,080:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,081:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,082:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,083:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,084:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,086:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,087:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,088:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,089:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,091:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,092:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,093:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,139:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,140:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,141:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,169:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,170:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,176:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,178:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,178:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,179:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,180:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,183:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,184:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,185:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,218:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,247:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,275:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,302:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,333:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,334:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,335:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,364:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,365:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,368:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,370:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,380:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,462:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,464:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:58,493:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:59,546:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:16:59,976:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,014:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,015:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,016:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,017:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,018:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,018:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,020:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,021:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,021:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,022:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,023:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,023:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,024:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,025:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,025:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,027:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,027:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,028:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,029:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,030:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,030:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,032:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,033:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,033:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,034:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,034:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,035:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,036:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,036:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,037:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,038:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-05 17:17:00,039:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Unfiltered MS2 Size:  9184  Compounds with  9184  MS2 Spectra
# 9078

# %%
# 134 minutes
tally_neg = []
for f in neg_orbi_datasets:
    list_khipus, all_assigned_fids, list_features = get_comprehensive_stats_per_dataset(
        f, dict_tablefiles, dict_rtwindow, 'neg'
        )

    list_khipus = sorted(list_khipus, key=lambda x: x['neutral_formula_mass'], reverse=True)
    remaining_features = [f for f in list_features if f['id'] not in all_assigned_fids]
    
    # by isf_candidate_fragments
    explained_khipu_ids, explained_feature_ids, delta_values_used = explain_a_dataset(
        list_khipus, remaining_features, isf_candidate_fragments, 
        rt_stdev=dict_rtwindow[f]
        )
    
    # by MoNA MS2
    have_precursors, matched2 = explain_a_dataset_byMS2(
        list_khipus, tree_MS2flist, rt_stdev=dict_rtwindow[f])
    delta_values_ms2 = []
    for x in matched2:
        delta_values_ms2 += x[2]
    
    tally_neg.append(
        {
            'study': f,
            'num_khipus': len(list_khipus),
            'num_features':  len(list_features),
            'mzdelta_explained_khipus': len(set(explained_khipu_ids)), 
            'mzdelta_explained_features': len(set(explained_feature_ids)),
            'freq_delta_values_used': delta_values_used,
            'have_precursors': len(have_precursors),
            'ms2_explained_features': len(matched2),
            'delta_values_ms2': delta_values_ms2,
        }
    )
# Out:
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM4_35', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_03', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_04', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_05', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_06', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_07', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_08', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_09', 'QXA13POL20180807_MSSM0118ML_HUMAN_SERUM1_10']
# Read 35496 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Constructed 2576 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 461 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 305 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'CB179-A', 'CB126-A', 'CB126-V', 'CB127-A', 'CB127-V', 'CB128-V', 'CB129-A', 'CB129-V', 'CB130-A']
# Read 103095 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Constructed 8485 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 2438 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 151 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '71', '314', '315', '316', '317', '319', '32', '320', '321']
# Read 94433 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Constructed 7947 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 1884 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 119 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'QC2', 'ACN_0_A', 'ACN_0_B', 'ACN_0_BLANK', 'ACN_0_BLANK_01', 'ACN_0_C1', 'ACN_0_C2', 'ACN_0_C3', 'ACN_20C_A']
# Read 36361 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 40 features, highest peak at F5560
# Downsized input network with 31 features, highest peak at F15535
# Constructed 2992 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 444 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 25 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'QXA08POL20170920_HSLO010217VWBL_HUMAN_PLASMA5_17', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_03', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_05', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_06', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_08', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_10', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_13', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_15', 'QXA08POL20170918_HSLO010217VWBL_HUMAN_PLASMA1_18']
# Read 31406 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 30 features, highest peak at F14073
# Downsized input network with 29 features, highest peak at F22521
# Constructed 3142 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 324 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 13 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'VT_181109_M338_118', 'VT_181106_M338_026', 'VT_181106_M338_028', 'VT_181106_M338_030', 'VT_181106_M338_038', 'VT_181106_M338_040', 'VT_181106_M338_042', 'VT_181106_M338_044', 'VT_181106_M338_046']
# Read 22129 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 28 features, highest peak at F18355
# Downsized input network with 27 features, highest peak at F18151
# Constructed 1782 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 189 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 68 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '160701_neg_40', '160701_UDS_13', '160701_UDS_15', '160701_UDS_17', '160701_UDS_20', '160701_UDS_3', '160701_UDS_30', '160701_UDS_32', '160701_UDS_34']
# Read 129750 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 52 features, highest peak at F57781
# Downsized input network with 63 features, highest peak at F86456
# Downsized input network with 66 features, highest peak at F119571
# Downsized input network with 358 features, highest peak at F125466
# Downsized input network with 52 features, highest peak at F114090
# Downsized input network with 72 features, highest peak at F54017
# Downsized input network with 35 features, highest peak at F4560
# Downsized input network with 33 features, highest peak at F93663
# Downsized input network with 32 features, highest peak at F70022
# Downsized input network with 109 features, highest peak at F108201
# Downsized input network with 59 features, highest peak at F123673
# Downsized input network with 125 features, highest peak at F127711
# Downsized input network with 140 features, highest peak at F39364
# Downsized input network with 44 features, highest peak at F37784
# Downsized input network with 29 features, highest peak at F39478
# Downsized input network with 50 features, highest peak at F128264
# Downsized input network with 26 features, highest peak at F66526
# Downsized input network with 37 features, highest peak at F76218
# Downsized input network with 40 features, highest peak at F48080
# Downsized input network with 27 features, highest peak at F98495
# Downsized input network with 28 features, highest peak at F60895
# Downsized input network with 57 features, highest peak at F126819
# Downsized input network with 41 features, highest peak at F73459
# Downsized input network with 45 features, highest peak at F77312
# Downsized input network with 155 features, highest peak at F115529
# Downsized input network with 42 features, highest peak at F58539
# Downsized input network with 33 features, highest peak at F112014
# Downsized input network with 47 features, highest peak at F52335
# Downsized input network with 35 features, highest peak at F69861
# Downsized input network with 26 features, highest peak at F93998
# Downsized input network with 179 features, highest peak at F125745
# Downsized input network with 27 features, highest peak at F67719
# Downsized input network with 26 features, highest peak at F108734
# Downsized input network with 31 features, highest peak at F75853
# Downsized input network with 39 features, highest peak at F80004
# Downsized input network with 56 features, highest peak at F96086
# Downsized input network with 48 features, highest peak at F94838
# Downsized input network with 56 features, highest peak at F102558
# Downsized input network with 27 features, highest peak at F106389
# Downsized input network with 70 features, highest peak at F124672
# Downsized input network with 36 features, highest peak at F126458
# Downsized input network with 28 features, highest peak at F85472
# Downsized input network with 30 features, highest peak at F102678
# Downsized input network with 35 features, highest peak at F108865
# Downsized input network with 29 features, highest peak at F113816
# Downsized input network with 26 features, highest peak at F126522
# Downsized input network with 30 features, highest peak at F125558
# Downsized input network with 35 features, highest peak at F123515
# Downsized input network with 26 features, highest peak at F127172
# Downsized input network with 32 features, highest peak at F122531
# Downsized input network with 29 features, highest peak at F120148
# Constructed 16412 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Downsized input network with 37 features, highest peak at F116236
# Downsized input network with 47 features, highest peak at F126773
# Constructed 2630 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 225 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'NB_Plasma_ID_Library_mz_9_C18_Neg_019', '01_onset_NB_Plasma_Quant_C18_Neg_069', '02_onset_NB_Plasma_Quant_C18_Neg_067', '04_onset_NB_Plasma_Quant_C18_Neg_120', '05_onset_NB_Plasma_Quant_C18_Neg_140', '06_onset_NB_Plasma_Quant_C18_Neg_063', '07_onset_NB_Plasma_Quant_C18_Neg_113', '08_onset_NB_Plasma_Quant_C18_Neg_105', '10_onset_NB_Plasma_Quant_C18_Neg_086']
# Read 155337 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 31 features, highest peak at F48816
# Downsized input network with 37 features, highest peak at F8806
# Downsized input network with 27 features, highest peak at F6052
# Downsized input network with 30 features, highest peak at F62437
# Downsized input network with 35 features, highest peak at F138170
# Downsized input network with 42 features, highest peak at F121752
# Downsized input network with 33 features, highest peak at F25182
# Downsized input network with 27 features, highest peak at F74785
# Downsized input network with 57 features, highest peak at F86511
# Downsized input network with 44 features, highest peak at F100205
# Downsized input network with 37 features, highest peak at F137869
# Downsized input network with 32 features, highest peak at F130818
# Constructed 11490 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 1586 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 113 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'H-376', 'H-313', 'H-314', 'H-315', 'H-316', 'H-317', 'H-318', 'H-319', 'H-320']
# Read 18761 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 50 features, highest peak at F5552
# Constructed 2244 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 367 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 3 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'n389', 'n357', 'n358', 'n359', 'n360', 'n361', 'n362', 'n363', 'n364']
# Read 42056 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Constructed 3172 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 297 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 7 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'NB_Plasma_ID_Library_mz_9_C18_Neg_019', '01_onset_NB_Plasma_Quant_C18_Neg_069', '02_onset_NB_Plasma_Quant_C18_Neg_067', '04_onset_NB_Plasma_Quant_C18_Neg_120', '05_onset_NB_Plasma_Quant_C18_Neg_140', '06_onset_NB_Plasma_Quant_C18_Neg_063', '07_onset_NB_Plasma_Quant_C18_Neg_113', '08_onset_NB_Plasma_Quant_C18_Neg_105', '09_onset_NB_Plasma_Quant_C18_Neg_054']
# Read 159869 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 34 features, highest peak at F102644
# Downsized input network with 29 features, highest peak at F45983
# Downsized input network with 36 features, highest peak at F113217
# Downsized input network with 46 features, highest peak at F4807
# Downsized input network with 27 features, highest peak at F113986
# Downsized input network with 26 features, highest peak at F113983
# Downsized input network with 28 features, highest peak at F96585
# Downsized input network with 161 features, highest peak at F112637
# Downsized input network with 99 features, highest peak at F130863
# Downsized input network with 28 features, highest peak at F28625
# Downsized input network with 72 features, highest peak at F66572
# Downsized input network with 29 features, highest peak at F117665
# Downsized input network with 96 features, highest peak at F99527
# Downsized input network with 36 features, highest peak at F96160
# Downsized input network with 33 features, highest peak at F135009
# Downsized input network with 37 features, highest peak at F125720
# Downsized input network with 38 features, highest peak at F35897
# Downsized input network with 29 features, highest peak at F61820
# Downsized input network with 32 features, highest peak at F42065
# Downsized input network with 28 features, highest peak at F50399
# Downsized input network with 82 features, highest peak at F99837
# Downsized input network with 30 features, highest peak at F122299
# Downsized input network with 39 features, highest peak at F79630
# Downsized input network with 28 features, highest peak at F155693
# Constructed 12343 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Downsized input network with 26 features, highest peak at F120374
# Downsized input network with 28 features, highest peak at F96786
# Constructed 2043 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 124 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'CC30', 'CC1', 'CC10', 'CC11', 'CC12', 'CC13', 'CC14', 'CC15', 'CC16']
# Read 71691 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 43 features, highest peak at F27100
# Downsized input network with 37 features, highest peak at F49016
# Constructed 8730 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 864 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 107 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', '259', '21', '210', '211', '213', '214', '215', '216', '217']
# Read 117930 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 26 features, highest peak at F4843
# Downsized input network with 44 features, highest peak at F86859
# Constructed 13222 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 1843 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 102 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'COV2-100-', 'COV2-02-', 'COV2-03-', 'COV2-04-', 'COV2-05-', 'COV2-07-', 'COV2-08-', 'COV2-09-', 'COV2-10-']
# Read 25426 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 59 features, highest peak at F14535
# Downsized input network with 48 features, highest peak at F6758
# Downsized input network with 29 features, highest peak at F12284
# Downsized input network with 29 features, highest peak at F1777
# Downsized input network with 26 features, highest peak at F22015
# Downsized input network with 29 features, highest peak at F11659
# Downsized input network with 40 features, highest peak at F22081
# Downsized input network with 38 features, highest peak at F15887
# Downsized input network with 72 features, highest peak at F20260
# Downsized input network with 26 features, highest peak at F20878
# Downsized input network with 36 features, highest peak at F16810
# Constructed 2983 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 521 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 17 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'BD20', 'BD01', 'BD02', 'BD03', 'BD04', 'BD05', 'BD06', 'BD07', 'BD08']
# Read 89009 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 43 features, highest peak at F39408
# Downsized input network with 67 features, highest peak at F19938
# Downsized input network with 26 features, highest peak at F67168
# Downsized input network with 31 features, highest peak at F71142
# Downsized input network with 31 features, highest peak at F48418
# Downsized input network with 31 features, highest peak at F42682
# Downsized input network with 26 features, highest peak at F46856
# Downsized input network with 29 features, highest peak at F69117
# Downsized input network with 36 features, highest peak at F66154
# Downsized input network with 40 features, highest peak at F83728
# Downsized input network with 39 features, highest peak at F78400
# Downsized input network with 28 features, highest peak at F86839
# Downsized input network with 31 features, highest peak at F84773
# Downsized input network with 30 features, highest peak at F68186
# Downsized input network with 62 features, highest peak at F68286
# Downsized input network with 53 features, highest peak at F88752
# Downsized input network with 31 features, highest peak at F71455
# Downsized input network with 40 features, highest peak at F69567
# Downsized input network with 35 features, highest peak at F76230
# Downsized input network with 42 features, highest peak at F81137
# Downsized input network with 28 features, highest peak at F87141
# Constructed 6675 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# ...
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 866 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 106 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'AG-31_r4-', 'AG-100_r71-', 'AG-101_r66-', 'AG-102_r104-', 'AG-103_r47-', 'AG-104_r2-', 'AG-105_r91-', 'AG-106_r5-', 'AG-107_r96-']
# Read 31880 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 213 features, highest peak at F4319
# Downsized input network with 51 features, highest peak at F10833
# Downsized input network with 32 features, highest peak at F2382
# Downsized input network with 50 features, highest peak at F6137
# Downsized input network with 28 features, highest peak at F4410
# Downsized input network with 240 features, highest peak at F12792
# Downsized input network with 178 features, highest peak at F20617
# Constructed 4191 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Downsized input network with 49 features, highest peak at F16884
# Constructed 770 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 13 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'QE2_lm_5_Johnson-Shahin_45[PR0601]n', 'QE2_lm_5_Johnson-Shahin_30[PF0087]n', 'QE2_lm_5_Johnson-Shahin_31[PF0459]n', 'QE2_lm_5_Johnson-Shahin_32[PF0137]n', 'QE2_lm_5_Johnson-Shahin_33[PF0334]n', 'QE2_lm_5_Johnson-Shahin_34[PR0560]n', 'QE2_lm_5_Johnson-Shahin_35[PR0475]n', 'QE2_lm_5_Johnson-Shahin_36[PF0400]n', 'QE2_lm_5_Johnson-Shahin_37[PF0623]n']
# Read 162593 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 1475 features, highest peak at F78741
# Downsized input network with 295 features, highest peak at F85185
# Downsized input network with 64 features, highest peak at F31603
# Downsized input network with 85 features, highest peak at F90002
# Downsized input network with 26 features, highest peak at F83195
# Downsized input network with 33 features, highest peak at F4522
# Downsized input network with 34 features, highest peak at F64513
# Downsized input network with 37 features, highest peak at F4559
# Downsized input network with 40 features, highest peak at F86657
# Downsized input network with 30 features, highest peak at F33559
# Downsized input network with 72 features, highest peak at F47169
# Downsized input network with 26 features, highest peak at F8828
# Downsized input network with 37 features, highest peak at F32775
# Downsized input network with 30 features, highest peak at F15884
# Downsized input network with 26 features, highest peak at F55413
# Downsized input network with 31 features, highest peak at F104742
# Downsized input network with 34 features, highest peak at F17180
# Downsized input network with 32 features, highest peak at F78504
# Downsized input network with 29 features, highest peak at F161631
# Downsized input network with 31 features, highest peak at F83014
# Downsized input network with 29 features, highest peak at F30734
# Downsized input network with 26 features, highest peak at F71616
# Downsized input network with 31 features, highest peak at F60062
# Downsized input network with 29 features, highest peak at F75274
# Downsized input network with 29 features, highest peak at F128522
# Downsized input network with 38 features, highest peak at F20047
# Downsized input network with 27 features, highest peak at F66844
# Downsized input network with 33 features, highest peak at F76916
# Downsized input network with 32 features, highest peak at F135621
# Downsized input network with 29 features, highest peak at F118560
# Constructed 19888 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Downsized input network with 775 features, highest peak at F78741
# Constructed 3124 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 68 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'Nexus_techmix-4neg-1', 'Nexus_D21_4neg-15', 'Nexus_D21_4neg-16', 'Nexus_D21_4neg-17', 'Nexus_D21_4neg-19', 'Nexus_D21_4neg-20', 'Nexus_D21_4neg-31', 'Nexus_D21_4neg-32', 'Nexus_D21_4neg-35']
# Read 18663 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 56 features, highest peak at F5735
# Downsized input network with 40 features, highest peak at F5703
# Downsized input network with 34 features, highest peak at F14486
# Downsized input network with 34 features, highest peak at F3405
# Downsized input network with 31 features, highest peak at F15100
# Downsized input network with 32 features, highest peak at F15299
# Downsized input network with 32 features, highest peak at F1693
# Downsized input network with 87 features, highest peak at F16675
# Downsized input network with 72 features, highest peak at F16158
# Downsized input network with 27 features, highest peak at F14849
# Downsized input network with 27 features, highest peak at F13222
# Constructed 2357 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 349 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 3 khipus in this round.
#
#
# table header looks like:
#    ['id_number', 'mz', 'rtime', 'rtime_left_base', 'rtime_right_base', 'parent_masstrack_id', 'peak_area', 'cSelectivity', 'goodness_fitting', 'snr', 'detection_counts', 'VT_191125_M418_018', 'VT_191125_M418_002', 'VT_191125_M418_004', 'VT_191125_M418_006', 'VT_191125_M418_008', 'VT_191125_M418_010', 'VT_191125_M418_012', 'VT_191125_M418_014', 'VT_191125_M418_016']
# Read 24896 feature lines
#
#
# Multiple charges considered: [1, 2, 3]
#
#
# Khipu search grid:
#                M-H-       Na/H        K/H        ACN     NaCOOH
# M0        -1.007276  20.974664  36.948606  40.019273  66.980148
# 13C/12C   -0.003921  21.978019  37.951961  41.022628  67.983503
# 37Cl/35Cl  0.989724  22.971664  38.945606  42.016273  68.977148
# 13C/12C*2  0.999434  22.981374  38.955316  42.025983  68.986858
# 44Ca/40Ca  2.987524  24.969464  40.943406  44.014073  70.974948
# Downsized input network with 39 features, highest peak at F2939
# Downsized input network with 29 features, highest peak at F3016
# Downsized input network with 43 features, highest peak at F3056
# Downsized input network with 64 features, highest peak at F23681
# Downsized input network with 39 features, highest peak at F22665
# Downsized input network with 36 features, highest peak at F19193
# Downsized input network with 32 features, highest peak at F20045
# Downsized input network with 52 features, highest peak at F20542
# Constructed 2383 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 2x charged  Na/H, 2x charged  K/H, 2x charged  \
# M0                            -0.503638          9.983694        17.970665
# 13C/12C, 2x charged           -0.001961         10.485371        18.472342
# 37Cl/35Cl, 2x charged          0.494862         10.982194        18.969165
# 13C/12C*2, 2x charged          0.499717         10.987049        18.974020
# 44Ca/40Ca, 2x charged          1.493762         11.981094        19.968065
#
#                        ACN, 2x charged  NaCOOH, 2x charged
# M0                           19.505998           32.986436
# 13C/12C, 2x charged          20.007676           33.488113
# 37Cl/35Cl, 2x charged        20.504498           33.984936
# 13C/12C*2, 2x charged        20.509353           33.989791
# 44Ca/40Ca, 2x charged        21.503398           34.983836
# Constructed 335 khipus in this round.
#
#
# Khipu search grid:
#                        M-H-, 3x charged  Na/H, 3x charged  K/H, 3x charged  \
# M0                            -0.335759          6.320037        11.644684
# 13C/12C, 3x charged           -0.001307          6.654489        11.979136
# 37Cl/35Cl, 3x charged          0.329908          6.985704        12.310351
# 13C/12C*2, 3x charged          0.333145          6.988940        12.313588
# 44Ca/40Ca, 3x charged          0.995841          7.651637        12.976284
#
#                        ACN, 3x charged  NaCOOH, 3x charged
# M0                           12.668240           21.655198
# 13C/12C, 3x charged          13.002692           21.989650
# 37Cl/35Cl, 3x charged        13.333907           22.320865
# 13C/12C*2, 3x charged        13.337143           22.324102
# 44Ca/40Ca, 3x charged        13.999840           22.986798
# Constructed 143 khipus in this round.

# %%
len(tally_neg), tally_neg[8]['ms2_explained_features'], tally_neg[8]['mzdelta_explained_features']
# Out:
# (23, 215, 486)

# %%
with open('isfExplained_result_tally_neg.json', 'w', encoding='utf-8') as f:
    json.dump(tally_neg, f,  ensure_ascii=False, indent=2)

# %%
for x in tally_pos + tally_neg:
    print(x['study'], '\n', x['num_features'], x['mzdelta_explained_features'], x['ms2_explained_features'])
# Out:
# ST001237_HILICpos_B2_ppm5_3524314
#  42798 1061 993
# ST002937_HILICpos_ST002937_pos_hilic_batch_1_zip_B2_ppm5_351419
#  124335 1884 993
# ST002112_HILICpos_B2_ppm5_3545123
#  82833 1247 993
# MTBLS4187_HILICpos_HILIC_ppm5_3521045
#  50806 879 993
# MTBLS3852_HILICpos__ppm5_3533848
#  179960 1402 993
# MTBLS1465_HILICpos__ppm5_3505731
#  60462 851 993
# ST001335_HILICpos__ppm5_35132731
#  31061 680 993
# ST001736_RPpos__ppm5_34232333
#  17971 702 993
# MTBLS136_RPpos_B17_ppm5_3583756
#  18660 650 844
# ST002200_RPpos_17min_B3_ppm5_3422144
#  35608 720 1256
# ST001181_RPpos_B11_ppm5_36163417
#  28256 189 1256
# ST002443_RPpos_B3_ppm5_81311338
#  23696 199 1256
# ST002118_RPpos_B1_ppm5_36115624
#  38456 615 1256
# ST003315_RPpos__ppm5_813163714
#  16471 349 695
# ST002112_RPpos_B3_ppm5_356194
#  81564 2365 993
# MTBLS4187_RPpos__ppm5_3522135
#  101807 1766 993
# ST002049_RPpos_B1_ppm5_352018
#  39256 561 1256
# MTBLS2245_RPpos_Method 2_B1_ppm5_81318250
#  15960 587 695
# ST001430_RPpos_B1_ppm5_3423140
#  59122 787 989
# MTBLS205_RPpos_B1_ppm5_3531210
#  14459 767 695
# ST001243_RPpos__ppm5_35185010
#  18431 527 993
# ST002521_RPpos_B3_ppm5_3662420
#  84382 1745 993
# MTBLS2245_HILICneg_Method 4_B5_ppm5_81318755
#  27849 393 146
# ST002937_HILICneg_ST002937_neg_hilic_batch_1_zip_B3_ppm5_353747
#  77959 859 291
# ST002112_HILICneg_B3_ppm5_3552830
#  71631 924 215
# MTBLS1465_HILICneg__ppm5_35195
#  28439 342 215
# MTBLS205_HILICneg__ppm5_353536
#  23169 397 215
# ST002331_RPneg_B5_ppm5_3655219
#  17173 117 215
# MTBLS476_RPneg__ppm5_3551151
#  80601 1460 215
# MTBLS4294_RPneg__ppm5_3542818
#  124271 986 215
# ST002200_RPneg_5min_B4_ppm5_3423035
#  12512 486 215
# ST001430_RPneg_B4_ppm5_350239
#  34190 322 215
# ST002238_RPneg__ppm5_36104557
#  125278 1115 291
# ST002521_RPneg_B2_ppm5_3673943
#  48156 861 215
# ST002112_RPneg_B2_ppm5_3572946
#  82253 1350 215
# ST001736_RPneg__ppm5_34232652
#  16674 685 215
# ST002554_RPneg__ppm5_3611102
#  69887 314 291
# MTBLS1465_RPneg__ppm5_3514212
#  105330 1622 180
# MTBLS4187_RPneg__ppm5_3524019
#  51906 320 215
# MTBLS205_RPneg__ppm5_3531433
#  33264 680 180
# ST001240_RPneg__ppm5_35193041
#  27522 1007 215
# ST003315_RPneg__ppm5_813164016
#  19897 1400 215
# ST000919_RPneg_B1_ppm5_363371
#  103411 2669 215
# ST001243_RPneg__ppm5_3518535
#  11576 251 215
# ST001335_RPneg__ppm5_35133334
#  17822 248 146

# %% [markdown]
# # Conclusion
#
# This notebook tests how many features can be explained by frequent fragments or MS2 peaks.
#
# The RT window does not guanrantee coelution. Next notebook will test the real RT distribution.
#
# The notebook 6 will recalculate many features can be explained by khipu using comprehensive ion lists.
